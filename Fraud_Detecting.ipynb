# %% [markdown]
# ## Credit Card Fraud Detection
#
# 약 28만건의 신용카드 거래 데이터 중에서 이상거래(Fraud)를 감지해내는 프로그램

# %% [markdown]
# # Module Import

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# 필요한 라이브러리들을 불러옵니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 구글 Colab을 사용할 경우, 적절한 작업경로를 지정해줍니다.

# %% [markdown]
# # Data Load

# %%
df = pd.read_csv("/content/drive/My Drive/dataset/creditcard.csv", delimiter=',', dtype=np.float32)
print(df.shape)
df.head()
# Out:
# (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798279 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28      Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.619995    0.0
# 1  0.125895 -0.008983  0.014724    2.690000    0.0
# 2 -0.139097 -0.055353 -0.059752  378.660004    0.0
# 3 -0.221929  0.062723  0.061458  123.500000    0.0
# 4  0.502292  0.219422  0.215153   69.989998    0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# Pandas로 csv파일을 불러와서 확인해 줍니다. df라는 변수에 데이터가 제대로 저장되었는지 head 명령어를 통해 확인해 줍니다.

# %% [markdown]
# # Missing Value Check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float32
#  1   V1      284807 non-null  float32
#  2   V2      284807 non-null  float32
#  3   V3      284807 non-null  float32
#  4   V4      284807 non-null  float32
#  5   V5      284807 non-null  float32
#  6   V6      284807 non-null  float32
#  7   V7      284807 non-null  float32
#  8   V8      284807 non-null  float32
#  9   V9      284807 non-null  float32
#  10  V10     284807 non-null  float32
#  11  V11     284807 non-null  float32
#  12  V12     284807 non-null  float32
#  13  V13     284807 non-null  float32
#  14  V14     284807 non-null  float32
#  15  V15     284807 non-null  float32
#  16  V16     284807 non-null  float32
#  17  V17     284807 non-null  float32
#  18  V18     284807 non-null  float32
#  19  V19     284807 non-null  float32
#  20  V20     284807 non-null  float32
#  21  V21     284807 non-null  float32
#  22  V22     284807 non-null  float32
#  23  V23     284807 non-null  float32
#  24  V24     284807 non-null  float32
#  25  V25     284807 non-null  float32
#  26  V26     284807 non-null  float32
#  27  V27     284807 non-null  float32
#  28  V28     284807 non-null  float32
#  29  Amount  284807 non-null  float32
#  30  Class   284807 non-null  float32
# dtypes: float32(31)
# memory usage: 33.7 MB

# %% [markdown]
# 불러온 데이터를 조금 더 구체적으로 살펴봅니다. 각 변수에 대해서 missing value가 존재하는지 확인합니다. 만약 missing value가 존재할 경우 count 컬럼에 missing value의 숫자가 기록됩니다. 이 데이터에서는 missing value가 존재하지 않음을 확인할 수 있습니다. 또한 데이터 타입과 메모리 사용량도 확인 가능합니다.

# %%
df.isnull().sum() / df.shape[0]
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %% [markdown]
# 만약 missing value가 존재한다면, 몇개의 missing value가 존재하는지 확인해 줍니다. missing value의 존재를 확인했다면 해당 missing value가 존재하는는 row를 삭제하거나 적절한 값으로 missing value를 채워주도록 합니다. 여기서 적절한 값을 계산하는 방법은 여러가지가 존재할 수 있으며, 가장 간단하게는 평균이나 중간값을 사용할 수 있습니다.

# %% [markdown]
# # Correlation Visualize

# %%
import seaborn
f, ax = plt.subplots(figsize = (25,15))
seaborn.heatmap(df.corr(), annot=True, linewidths=0.3, fmt="0.2f", ax=ax, cmap="viridis")
plt.show()

# %% [markdown]
# Feature들 사이의 상관관계를 확인합니다. Credit card 데이터의 경우에는 이미 한번 PCA를 거친 데이터이기 때문에 Feature들 사이의 상관관계가 매우 낮게 나옵니다. 그러나 만약 Feature들 간의 상관관계가 높게 나오는 상황을 마주하게 된다면 VIF를 통해서 다중공선성을 확인해주는것이 좋습니다.

# %% [markdown]
# # EDA
# 데이터의 전체적인 구조를 살펴봅니다.

# %%
print(df["Class"].value_counts())
count_classes = pd.value_counts(df["Class"], sort=True)
count_classes.head()
print()

print(df["Class"].value_counts(normalize=True))
# Out:
# 0.0    284315
# 1.0       492
# Name: Class, dtype: int64
#
# 0.0    0.998273
# 1.0    0.001727
# Name: Class, dtype: float64

# %% [markdown]
# 0.0 : 정상거래
# 1.0 : 이상거래
#
# 정상거래는 28만 4315건, 이상거래는 492건이 존재합니다.
# 전체 데이터셋에서 오직 0.0017%가 이상거래이므로 심각한 imbalance가 존재하는 dataset임을 파악할 수 있습니다. 그러므로 일반적인 상황에서 주로 사용되는 Accuracy를 사용해서 모델의 Performance를 측정하기 어렵다는 결론이 도출됩니다. 따라서 모델을 설계할 때 Precision, Recall, 그리고 F1 Score를 사용하도록 디자인 해줍니다.

# %%
labels = ["Normal", "Fraud"]
count_classes.plot(kind="bar")
plt.xticks(range(2), labels)
plt.title("Transaction Class Distribution")
# Out:
# Text(0.5, 1.0, 'Transaction Class Distribution')

# %% [markdown]
# Data imabalance가 얼마나 심한지 시각화를 통해서 확인합니다.

# %%
df.drop(columns = "Time", inplace=True)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798279 -0.137458  0.141267
#
#         V25       V26       V27       V28      Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.619995    0.0
# 1  0.167170  0.125895 -0.008983  0.014724    2.690000    0.0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.660004    0.0
# 3  0.647376 -0.221929  0.062723  0.061458  123.500000    0.0
# 4 -0.206010  0.502292  0.219422  0.215153   69.989998    0.0
#
# [5 rows x 30 columns]

# %% [markdown]
# Time 이라는 Feature는 단순히 신용카드 거래가 이루어진 순서를 기록한 것이기 때문에 분석에 크게 도움이 되지 않습니다. \
# 그러므로 데이터 테이블에서 배제시켜 줍니다.

# %%
x_data = df.iloc[:,0:-1].values
y_data = df.iloc[:,[-1]].values

x_data = np.array(x_data, dtype=np.float32)
y_data = np.array(y_data, dtype=np.float32)

print(x_data.shape, y_data.shape)
# Out:
# (284807, 29) (284807, 1)

# %% [markdown]
# Feature들로 이루어진 x_data와, label을 나타내는 y_data로 원본 데이터를 분리시켜 줍니다. \
# 분리된 데이터는 앞으로 계산을 해주어야 하기 때문에 동일한 타입의 실수형 데이터로 저장합니다.

# %% [markdown]
# # Data Preprocessing - Normalize

# %%
scaler = MinMaxScaler()
x_data = scaler.fit_transform(x_data)
print(x_data)
# Out:
# [[9.3519241e-01 7.6649040e-01 8.8136494e-01 ... 4.1897613e-01
#   3.1269664e-01 5.8237929e-03]
#  [9.7854203e-01 7.7006662e-01 8.4029853e-01 ... 4.1634512e-01
#   3.1342265e-01 1.0470528e-04]
#  [9.3521708e-01 7.5311762e-01 8.6814088e-01 ... 4.1548926e-01
#   3.1191131e-01 1.4738923e-02]
#  ...
#  [9.9090487e-01 7.6407969e-01 7.8110206e-01 ... 4.1659316e-01
#   3.1258485e-01 2.6421540e-03]
#  [9.5420909e-01 7.7285570e-01 8.4958714e-01 ... 4.1851953e-01
#   3.1524515e-01 3.8923896e-04]
#  [9.4923186e-01 7.6525640e-01 8.4960151e-01 ... 4.1646636e-01
#   3.1340083e-01 8.4464857e-03]]

# %% [markdown]
# 데이터의 Scale에 따라서 결과가 왜곡되는 것을 방지하기 위해서 MinMaxScaler를 통해서 데이터가 0~1 사이의 값을 지니도록 조정해 줍니다.

# %% [markdown]
# # Parameter Initilization

# %%
tf.random.set_seed(2022)

W = tf.Variable(tf.random.normal([29,1], mean=0.0))
b = tf.Variable(tf.random.normal([1], mean=0.0))

# %% [markdown]
# W: 앞에는 input dimension, 뒤에는 output dimension으로 설정해야 합니다.\
# b: output dimension과 동일하게 설정합니다.

# %% [markdown]
# # Hypothesis Define

# %%
def hypothesis(x):
  z = tf.matmul(x,W) + b
  sigmoid = 1 / (1 + tf.exp(-z))
  return sigmoid

# %% [markdown]
# Feature와 Label 사이의 관계를 정의하는 부분입니다.\
# 여기서는 이진분류 문제에 주로 사용되는 Logistic Regression을 hypothesis로 설정해 주었습니다.

# %% [markdown]
# # Cost Function Define

# %%
def cost_function(H, Y):
  cost = -tf.reduce_mean( Y*tf.math.log(H) + (1-Y)*tf.math.log(1-H))
  return cost

# %% [markdown]
# Cost Function 혹은 Loss Function으로 불립니다. \
# 여기서는 마찬가지로 이진분류에서 주로 사용되는 Cross Entropy를 cost function으로 설정해 주었습니다.

# %% [markdown]
# # Metric Define

# %%
def accuracy(hypo, label):
  predicted = tf.cast( hypo > 0.5, dtype = tf.float32)
  accuracyd = tf.reduce_mean(tf.cast(tf.equal(predicted, label), dtype=tf.float32))
  return accuracyd

# %% [markdown]
# 실제 모델의 퍼포먼스를 측정하는 기준을 설정합니다. \
# 일반적으로 가장 많이 쓰이는 Accuracy를 우선은 설정해 줍니다.

# %% [markdown]
# # Hyper-parameter Setting

# %%
learning_rate = 0.0001
optimizer = tf.optimizers.SGD(learning_rate)

# %% [markdown]
# 학습을 진행하기 위해서 우리가 지정해 주어야 하는 변수를 Hyper-parameter라고 합니다. \
# 대표적인 하이퍼 파라미터는 learning rate, optimizer, epochs, actvation function, number of layer, number of neuron 같은 것들이 존재합니다. \
# 지금은 딥러닝 모델을 사용하는 것이 아니기 때문에 Logistic Regression 학습에 필요한 learning rate와 optimizer만 설정해 주었습니다.

# %% [markdown]
# # Training

# %%
for step in range(2022):
  with tf.GradientTape() as g:
    pred = hypothesis(x_data)
    cost = cost_function(pred, y_data)
    
    gradients = g.gradient(cost, [W,b])
  
  optimizer.apply_gradients(zip(gradients, [W,b]))

  if step % 200 == 0:
    print(f"step: {step}, loss: {cost.numpy()}")

w_hat = W.numpy()
b_hat = b.numpy()
# Out:
# step: 0, loss: 0.026920180767774582
# step: 200, loss: 0.02684672921895981
# step: 400, loss: 0.02677365578711033
# step: 600, loss: 0.02670133300125599
# step: 800, loss: 0.026629552245140076
# step: 1000, loss: 0.02655830793082714
# step: 1200, loss: 0.026487411931157112
# step: 1400, loss: 0.0264168418943882
# step: 1600, loss: 0.02634689025580883
# step: 1800, loss: 0.026278041303157806
# step: 2000, loss: 0.026209723204374313

# %% [markdown]
# Backpropagation을 통해서 최적의 W와 b를 계속해서 업데이트 해줍니다. \
# 최종적으로 업데이트된 값을 w_hat과 b_hat에 저장합니다.

# %% [markdown]
# # 정확도 측정

# %%
acc = accuracy(hypothesis(x_data), y_data).numpy()
print(f"Accuracy: {acc}")
# Out:
# Accuracy: 0.9982725381851196

# %% [markdown]
# 99.83%의 상당히 높은 Accuracy를 보입니다. \
# 그러나 위에서 살펴본 바에 의하면 dataset이 매우 imbalance 했으므로, Accuracy는 모델을 평가하는 적절한 metric이 될 수 없습니다. \
# 그러므로 Precision과 Recall의 측면에서 모델을 다시한번 평가해 봅니다.

# %% [markdown]
# # Precision, Recall, F1 Score

# %%
# metric
from sklearn.metrics import accuracy_score, classification_report, f1_score

# %%
predicted_x = tf.cast( hypothesis(x_data) > 0.5, dtype = tf.float32)

# %%
print("Accuracy = ", accuracy_score(predicted_x, y_data))
print("Report = \n", classification_report(predicted_x, y_data))
# Out:
# Accuracy =  0.9982725143693799
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Report =
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00    284807
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           1.00    284807
#    macro avg       0.50      0.50      0.50    284807
# weighted avg       1.00      1.00      1.00    284807
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# 대안적인 metric의 관점에서 Logisic Regression 모델을 평가해 봤을 때, Fraud transaction을 거의 잡아내지 못하는 것을 볼 수 있습니다. \
# 그러므로 다른 모델을 통해서 접근할 필요가 있습니다. \
#
#
# * Precision: 모델이 True라고 분류한 것 중에서 실제 True가 차지하는 비중
# * Recall: 실제 True 중에서 모델이 True라고 분류한 데이터의 비중
# * F1 score: Precision과 Recall의 조화평균

# %% [markdown]
# ## Neural Networks
# 인공신경망 모델을 통해서 Fraud Detecting을 시도해 봅니다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from sklearn.model_selection import train_test_split
from keras import optimizers, metrics, callbacks

# %% [markdown]
# # Dataset Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2,  random_state=22)

# %% [markdown]
# 학습에 사용할 training set과 퍼포먼스 측정에 사용할 test set을 8:2로 나누어 줍니다.

# %%
x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size = 0.2, random_state=22)

# %% [markdown]
# EarlyStopping(=callbacks) 사용을 위해서 validation set을 만들어 주어야 합니다.\
# 기존의 training set 데이터를 또다시 8:2로 나누어 training set과 validation set으로 나누어 줍니다.

# %%
print(x_train.shape, y_train.shape)
print(x_validate.shape, y_validate.shape)
print(x_test.shape, y_test.shape)
# Out:
# (182276, 29) (182276, 1)
# (45569, 29) (45569, 1)
# (56962, 29) (56962, 1)

# %% [markdown]
# # Neural Network Design

# %%
model = Sequential([
    Dense(256, activation='relu', input_shape=(x_train.shape[-1],)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(16, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(10, activation='softmax'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(1, activation='sigmoid'),
])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 256)               7680
#
#  batch_normalization_18 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_22 (Dense)            (None, 128)               32896
#
#  batch_normalization_19 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 64)                8256
#
#  batch_normalization_20 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 64)                0
#
#  dense_24 (Dense)            (None, 32)                2080
#
#  batch_normalization_21 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 32)                0
#
#  dense_25 (Dense)            (None, 16)                528
#
#  batch_normalization_22 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_22 (Dropout)        (None, 16)                0
#
#  dense_26 (Dense)            (None, 10)                170
#
#  batch_normalization_23 (Bat  (None, 10)               40
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 10)                0
#
#  dense_27 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 53,645
# Trainable params: 52,633
# Non-trainable params: 1,012
# _________________________________________________________________

# %% [markdown]
# 자신만의 적절한 ANN 모델을 만들어 줍니다. \
# \
# Input Layer에서는 항상 input data의 dimension에 따라서 적절한 input_shape을 지정해 주어야합니다. HIdden Layer 사이의 activation function으로는 ReLU를 기본적으로 사용하며, 이진분류 문제이므로 Output Layer에서는 activation function을 꼭 sigmoid로 지정해 주어야 합니다. \
# \
# Hidden Layer마다 Drop out을 적용해서 Overfitting을 방지하도록 합니다. Batch Normalization도 적용해 주면서 학습이 보다 빠르고 안정적으로 진행되게끔 유도합니다.
# \
# \
# 이 모델에서는 Hidden Layer를 지날수록 점점 neuron의 숫자를 줄게하여 정보가 압축되도록 설계했고, Ouput Layer 직전의 Hidden Layer에서는 activation function으로 softmax를 사용했습니다.

# %% [markdown]
# # Model compile

# %%
model.compile(optimizer=optimizers.Adam(1e-4),
              loss = "binary_crossentropy",
              metrics =  [metrics.Recall(name="recall"),
                          metrics.Precision(name="precison")])

# %%
callbacks = [callbacks.ModelCheckpoint('epcoh.h5')]

# %% [markdown]
# 모델을 학습하는데 필요한 하이퍼 파라미터들을 지정해 줍니다. \
# \
# Optimizer는 일반적으로 가장 성능이 좋은 Adam을 사용해줍니다. \
# \
# Adam에 default 값으로 지정된 learning rate는 1e-3 입니다. 그러나 학습을 진행해 본 결과 learning rate이 너무 커서 학습이 불안정하게 진행되는 것이 포착되었습니다. 그러므로 learning rate을 1e-4로 더 낮추어서 적용해 줍니다. \
# \
# loss function으로는 이진분류에 적합한 binary crossentropy를 사용합니다.\
# \
# 최종적인 성능평가의 metric으로 precision과 recall을 지정해 줍니다. \
# \
# EarlyStopping을 적용해 줍니다. (callbacks)

# %% [markdown]
# # Training

# %%
history = model.fit(x_train, y_train,
                    validation_data = (x_validate, y_validate),
                    batch_size = 65536,
                    epochs = 1000,
                    callbacks = callbacks
                    )
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 2s 264ms/step - loss: 0.9691 - auc: 0.3784 - val_loss: 0.7101 - val_auc: 0.5000
# Epoch 2/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.9654 - auc: 0.3583 - val_loss: 0.7091 - val_auc: 0.3580
# Epoch 3/1000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.9631 - auc: 0.3633 - val_loss: 0.7090 - val_auc: 0.2068
# Epoch 4/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9558 - auc: 0.3686 - val_loss: 0.7092 - val_auc: 0.2113
# Epoch 5/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9609 - auc: 0.3531 - val_loss: 0.7090 - val_auc: 0.2014
# Epoch 6/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.9533 - auc: 0.3575 - val_loss: 0.7076 - val_auc: 0.4902
# Epoch 7/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9495 - auc: 0.3775 - val_loss: 0.7065 - val_auc: 0.4999
# Epoch 8/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9436 - auc: 0.3548 - val_loss: 0.7054 - val_auc: 0.5000
# Epoch 9/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.9463 - auc: 0.3657 - val_loss: 0.7044 - val_auc: 0.5000
# Epoch 10/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.9419 - auc: 0.3847 - val_loss: 0.7034 - val_auc: 0.5000
# Epoch 11/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.9406 - auc: 0.3574 - val_loss: 0.7024 - val_auc: 0.5000
# Epoch 12/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.9355 - auc: 0.3621 - val_loss: 0.7012 - val_auc: 0.5000
# Epoch 13/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.9361 - auc: 0.3651 - val_loss: 0.7001 - val_auc: 0.5000
# Epoch 14/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9277 - auc: 0.4156 - val_loss: 0.6988 - val_auc: 0.3806
# Epoch 15/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9259 - auc: 0.3828 - val_loss: 0.6975 - val_auc: 0.5576
# Epoch 16/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.9237 - auc: 0.3632 - val_loss: 0.6962 - val_auc: 0.5057
# Epoch 17/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.9241 - auc: 0.3732 - val_loss: 0.6948 - val_auc: 0.4998
# Epoch 18/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9196 - auc: 0.3833 - val_loss: 0.6934 - val_auc: 0.4999
# Epoch 19/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.9146 - auc: 0.4256 - val_loss: 0.6920 - val_auc: 0.5000
# Epoch 20/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.9130 - auc: 0.3598 - val_loss: 0.6907 - val_auc: 0.5000
# Epoch 21/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9113 - auc: 0.3545 - val_loss: 0.6893 - val_auc: 0.5024
# Epoch 22/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9094 - auc: 0.3607 - val_loss: 0.6880 - val_auc: 0.7751
# Epoch 23/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.9068 - auc: 0.3463 - val_loss: 0.6866 - val_auc: 0.6785
# Epoch 24/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.9038 - auc: 0.4005 - val_loss: 0.6852 - val_auc: 0.6101
# Epoch 25/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9041 - auc: 0.3820 - val_loss: 0.6838 - val_auc: 0.5120
# Epoch 26/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8991 - auc: 0.3930 - val_loss: 0.6825 - val_auc: 0.4998
# Epoch 27/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8958 - auc: 0.3656 - val_loss: 0.6811 - val_auc: 0.4999
# Epoch 28/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8932 - auc: 0.3492 - val_loss: 0.6797 - val_auc: 0.5110
# Epoch 29/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8932 - auc: 0.3629 - val_loss: 0.6783 - val_auc: 0.7079
# Epoch 30/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.8883 - auc: 0.3706 - val_loss: 0.6769 - val_auc: 0.8157
# Epoch 31/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8868 - auc: 0.3594 - val_loss: 0.6755 - val_auc: 0.7404
# Epoch 32/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8859 - auc: 0.3677 - val_loss: 0.6740 - val_auc: 0.6040
# Epoch 33/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8829 - auc: 0.4067 - val_loss: 0.6726 - val_auc: 0.5552
# Epoch 34/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8799 - auc: 0.3770 - val_loss: 0.6711 - val_auc: 0.4998
# Epoch 35/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8788 - auc: 0.3592 - val_loss: 0.6696 - val_auc: 0.5807
# Epoch 36/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8759 - auc: 0.3487 - val_loss: 0.6680 - val_auc: 0.7258
# Epoch 37/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8738 - auc: 0.3928 - val_loss: 0.6664 - val_auc: 0.7505
# Epoch 38/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.8709 - auc: 0.3854 - val_loss: 0.6647 - val_auc: 0.7005
# Epoch 39/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.8683 - auc: 0.3661 - val_loss: 0.6629 - val_auc: 0.6235
# Epoch 40/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8654 - auc: 0.3829 - val_loss: 0.6611 - val_auc: 0.5556
# Epoch 41/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8635 - auc: 0.4090 - val_loss: 0.6594 - val_auc: 0.6402
# Epoch 42/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8601 - auc: 0.3941 - val_loss: 0.6577 - val_auc: 0.7236
# Epoch 43/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8593 - auc: 0.3292 - val_loss: 0.6560 - val_auc: 0.7608
# Epoch 44/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8579 - auc: 0.3742 - val_loss: 0.6544 - val_auc: 0.7057
# Epoch 45/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.8544 - auc: 0.3758 - val_loss: 0.6528 - val_auc: 0.6236
# Epoch 46/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8531 - auc: 0.3778 - val_loss: 0.6512 - val_auc: 0.6412
# Epoch 47/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8508 - auc: 0.3746 - val_loss: 0.6495 - val_auc: 0.6820
# Epoch 48/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8454 - auc: 0.3796 - val_loss: 0.6479 - val_auc: 0.7191
# Epoch 49/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8463 - auc: 0.3869 - val_loss: 0.6461 - val_auc: 0.7666
# Epoch 50/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8442 - auc: 0.3751 - val_loss: 0.6444 - val_auc: 0.7455
# Epoch 51/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8429 - auc: 0.3861 - val_loss: 0.6428 - val_auc: 0.7074
# Epoch 52/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8387 - auc: 0.3820 - val_loss: 0.6412 - val_auc: 0.6935
# Epoch 53/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8375 - auc: 0.4379 - val_loss: 0.6396 - val_auc: 0.7462
# Epoch 54/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8341 - auc: 0.3793 - val_loss: 0.6380 - val_auc: 0.7850
# Epoch 55/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8342 - auc: 0.3880 - val_loss: 0.6364 - val_auc: 0.7768
# Epoch 56/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.8302 - auc: 0.4402 - val_loss: 0.6348 - val_auc: 0.7313
# Epoch 57/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8275 - auc: 0.4147 - val_loss: 0.6332 - val_auc: 0.6679
# Epoch 58/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.8269 - auc: 0.3986 - val_loss: 0.6317 - val_auc: 0.6408
# Epoch 59/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8240 - auc: 0.4177 - val_loss: 0.6300 - val_auc: 0.6148
# Epoch 60/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.8252 - auc: 0.3681 - val_loss: 0.6286 - val_auc: 0.6722
# Epoch 61/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8202 - auc: 0.3820 - val_loss: 0.6272 - val_auc: 0.6729
# Epoch 62/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.8163 - auc: 0.4197 - val_loss: 0.6258 - val_auc: 0.6684
# Epoch 63/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8167 - auc: 0.4014 - val_loss: 0.6245 - val_auc: 0.6521
# Epoch 64/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.8148 - auc: 0.3861 - val_loss: 0.6232 - val_auc: 0.6447
# Epoch 65/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.8152 - auc: 0.4365 - val_loss: 0.6219 - val_auc: 0.6286
# Epoch 66/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.8113 - auc: 0.4097 - val_loss: 0.6207 - val_auc: 0.6154
# Epoch 67/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8086 - auc: 0.4281 - val_loss: 0.6195 - val_auc: 0.6187
# Epoch 68/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.8054 - auc: 0.4486 - val_loss: 0.6182 - val_auc: 0.6318
# Epoch 69/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.8009 - auc: 0.4538 - val_loss: 0.6169 - val_auc: 0.6243
# Epoch 70/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.8022 - auc: 0.4089 - val_loss: 0.6157 - val_auc: 0.6258
# Epoch 71/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8017 - auc: 0.4713 - val_loss: 0.6145 - val_auc: 0.6194
# Epoch 72/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.8001 - auc: 0.4041 - val_loss: 0.6133 - val_auc: 0.6192
# Epoch 73/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.7988 - auc: 0.4042 - val_loss: 0.6121 - val_auc: 0.5919
# Epoch 74/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7976 - auc: 0.4450 - val_loss: 0.6109 - val_auc: 0.5714
# Epoch 75/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7926 - auc: 0.4334 - val_loss: 0.6096 - val_auc: 0.5635
# Epoch 76/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.7911 - auc: 0.4308 - val_loss: 0.6083 - val_auc: 0.5565
# Epoch 77/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7908 - auc: 0.4189 - val_loss: 0.6071 - val_auc: 0.5647
# Epoch 78/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.7910 - auc: 0.3830 - val_loss: 0.6059 - val_auc: 0.5738
# Epoch 79/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7871 - auc: 0.4173 - val_loss: 0.6048 - val_auc: 0.5876
# Epoch 80/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7846 - auc: 0.4266 - val_loss: 0.6037 - val_auc: 0.5703
# Epoch 81/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.7845 - auc: 0.4675 - val_loss: 0.6026 - val_auc: 0.5640
# Epoch 82/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.7805 - auc: 0.4081 - val_loss: 0.6015 - val_auc: 0.5583
# Epoch 83/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7809 - auc: 0.4656 - val_loss: 0.6005 - val_auc: 0.5533
# Epoch 84/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7790 - auc: 0.4307 - val_loss: 0.5994 - val_auc: 0.5539
# Epoch 85/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7779 - auc: 0.4518 - val_loss: 0.5982 - val_auc: 0.5552
# Epoch 86/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.7765 - auc: 0.4070 - val_loss: 0.5972 - val_auc: 0.5636
# Epoch 87/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7757 - auc: 0.4417 - val_loss: 0.5960 - val_auc: 0.5362
# Epoch 88/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7732 - auc: 0.4258 - val_loss: 0.5949 - val_auc: 0.5215
# Epoch 89/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.7686 - auc: 0.4275 - val_loss: 0.5938 - val_auc: 0.5138
# Epoch 90/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.7679 - auc: 0.4556 - val_loss: 0.5926 - val_auc: 0.5191
# Epoch 91/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7694 - auc: 0.4021 - val_loss: 0.5915 - val_auc: 0.5193
# Epoch 92/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7667 - auc: 0.4487 - val_loss: 0.5903 - val_auc: 0.5259
# Epoch 93/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7639 - auc: 0.4667 - val_loss: 0.5892 - val_auc: 0.5232
# Epoch 94/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.7633 - auc: 0.4404 - val_loss: 0.5880 - val_auc: 0.4954
# Epoch 95/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.7622 - auc: 0.4355 - val_loss: 0.5868 - val_auc: 0.4853
# Epoch 96/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.7584 - auc: 0.4863 - val_loss: 0.5858 - val_auc: 0.4678
# Epoch 97/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7569 - auc: 0.4369 - val_loss: 0.5846 - val_auc: 0.4600
# Epoch 98/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7567 - auc: 0.4466 - val_loss: 0.5834 - val_auc: 0.4578
# Epoch 99/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.7558 - auc: 0.4350 - val_loss: 0.5822 - val_auc: 0.4610
# Epoch 100/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7523 - auc: 0.4117 - val_loss: 0.5810 - val_auc: 0.4482
# Epoch 101/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7517 - auc: 0.4439 - val_loss: 0.5800 - val_auc: 0.4244
# Epoch 102/1000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.7487 - auc: 0.5033 - val_loss: 0.5789 - val_auc: 0.4189
# Epoch 103/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7471 - auc: 0.4652 - val_loss: 0.5777 - val_auc: 0.4144
# Epoch 104/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.7477 - auc: 0.4423 - val_loss: 0.5765 - val_auc: 0.4019
# Epoch 105/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7453 - auc: 0.4435 - val_loss: 0.5755 - val_auc: 0.3984
# Epoch 106/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7434 - auc: 0.4365 - val_loss: 0.5747 - val_auc: 0.3912
# Epoch 107/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7446 - auc: 0.4338 - val_loss: 0.5740 - val_auc: 0.3742
# Epoch 108/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7440 - auc: 0.4509 - val_loss: 0.5732 - val_auc: 0.3771
# Epoch 109/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7395 - auc: 0.4893 - val_loss: 0.5723 - val_auc: 0.3813
# Epoch 110/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.7383 - auc: 0.4788 - val_loss: 0.5715 - val_auc: 0.3846
# Epoch 111/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.7377 - auc: 0.4658 - val_loss: 0.5706 - val_auc: 0.4045
# Epoch 112/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7377 - auc: 0.4775 - val_loss: 0.5700 - val_auc: 0.4357
# Epoch 113/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.7359 - auc: 0.4397 - val_loss: 0.5695 - val_auc: 0.4771
# Epoch 114/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.7338 - auc: 0.4672 - val_loss: 0.5690 - val_auc: 0.4803
# Epoch 115/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.7322 - auc: 0.4466 - val_loss: 0.5684 - val_auc: 0.4920
# Epoch 116/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.7329 - auc: 0.4539 - val_loss: 0.5678 - val_auc: 0.5084
# Epoch 117/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.7307 - auc: 0.5119 - val_loss: 0.5673 - val_auc: 0.5100
# Epoch 118/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7285 - auc: 0.4485 - val_loss: 0.5668 - val_auc: 0.5187
# Epoch 119/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.7269 - auc: 0.4647 - val_loss: 0.5662 - val_auc: 0.5334
# Epoch 120/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7265 - auc: 0.4609 - val_loss: 0.5653 - val_auc: 0.5517
# Epoch 121/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7242 - auc: 0.4613 - val_loss: 0.5643 - val_auc: 0.5616
# Epoch 122/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7215 - auc: 0.4889 - val_loss: 0.5632 - val_auc: 0.5727
# Epoch 123/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7215 - auc: 0.4612 - val_loss: 0.5622 - val_auc: 0.5978
# Epoch 124/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7224 - auc: 0.4858 - val_loss: 0.5611 - val_auc: 0.6388
# Epoch 125/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7190 - auc: 0.4414 - val_loss: 0.5602 - val_auc: 0.6509
# Epoch 126/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.7180 - auc: 0.4359 - val_loss: 0.5594 - val_auc: 0.6560
# Epoch 127/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.7171 - auc: 0.4625 - val_loss: 0.5589 - val_auc: 0.6653
# Epoch 128/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7154 - auc: 0.4478 - val_loss: 0.5584 - val_auc: 0.6734
# Epoch 129/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7163 - auc: 0.4642 - val_loss: 0.5580 - val_auc: 0.6767
# Epoch 130/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7120 - auc: 0.4515 - val_loss: 0.5573 - val_auc: 0.6764
# Epoch 131/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.7137 - auc: 0.4533 - val_loss: 0.5567 - val_auc: 0.6730
# Epoch 132/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.7100 - auc: 0.5112 - val_loss: 0.5559 - val_auc: 0.6601
# Epoch 133/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.7107 - auc: 0.4828 - val_loss: 0.5550 - val_auc: 0.6523
# Epoch 134/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.7073 - auc: 0.4844 - val_loss: 0.5541 - val_auc: 0.6480
# Epoch 135/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7074 - auc: 0.4733 - val_loss: 0.5533 - val_auc: 0.6402
# Epoch 136/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7035 - auc: 0.4782 - val_loss: 0.5525 - val_auc: 0.6343
# Epoch 137/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7042 - auc: 0.5055 - val_loss: 0.5518 - val_auc: 0.6443
# Epoch 138/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.7027 - auc: 0.4910 - val_loss: 0.5510 - val_auc: 0.6545
# Epoch 139/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.7016 - auc: 0.4841 - val_loss: 0.5503 - val_auc: 0.6610
# Epoch 140/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.7004 - auc: 0.4628 - val_loss: 0.5497 - val_auc: 0.6545
# Epoch 141/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7026 - auc: 0.4690 - val_loss: 0.5494 - val_auc: 0.6479
# Epoch 142/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6973 - auc: 0.4918 - val_loss: 0.5488 - val_auc: 0.6435
# Epoch 143/1000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.6988 - auc: 0.4731 - val_loss: 0.5481 - val_auc: 0.6309
# Epoch 144/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6948 - auc: 0.5028 - val_loss: 0.5475 - val_auc: 0.6255
# Epoch 145/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6960 - auc: 0.4312 - val_loss: 0.5468 - val_auc: 0.6228
# Epoch 146/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6955 - auc: 0.5029 - val_loss: 0.5462 - val_auc: 0.6245
# Epoch 147/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6928 - auc: 0.5106 - val_loss: 0.5457 - val_auc: 0.6180
# Epoch 148/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6884 - auc: 0.5124 - val_loss: 0.5452 - val_auc: 0.6211
# Epoch 149/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6904 - auc: 0.4968 - val_loss: 0.5448 - val_auc: 0.6205
# Epoch 150/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6906 - auc: 0.5160 - val_loss: 0.5441 - val_auc: 0.6162
# Epoch 151/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6876 - auc: 0.5076 - val_loss: 0.5437 - val_auc: 0.6100
# Epoch 152/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6890 - auc: 0.4554 - val_loss: 0.5431 - val_auc: 0.6117
# Epoch 153/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6860 - auc: 0.5297 - val_loss: 0.5427 - val_auc: 0.6224
# Epoch 154/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6845 - auc: 0.4761 - val_loss: 0.5421 - val_auc: 0.6328
# Epoch 155/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6823 - auc: 0.4879 - val_loss: 0.5417 - val_auc: 0.6418
# Epoch 156/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6813 - auc: 0.4579 - val_loss: 0.5414 - val_auc: 0.6469
# Epoch 157/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6802 - auc: 0.4946 - val_loss: 0.5411 - val_auc: 0.6442
# Epoch 158/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.6792 - auc: 0.5163 - val_loss: 0.5406 - val_auc: 0.6469
# Epoch 159/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6789 - auc: 0.4565 - val_loss: 0.5403 - val_auc: 0.6471
# Epoch 160/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6780 - auc: 0.4419 - val_loss: 0.5399 - val_auc: 0.6475
# Epoch 161/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.6763 - auc: 0.5457 - val_loss: 0.5397 - val_auc: 0.6456
# Epoch 162/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.6744 - auc: 0.5252 - val_loss: 0.5394 - val_auc: 0.6420
# Epoch 163/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6730 - auc: 0.4783 - val_loss: 0.5391 - val_auc: 0.6565
# Epoch 164/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6727 - auc: 0.4959 - val_loss: 0.5388 - val_auc: 0.6676
# Epoch 165/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6727 - auc: 0.4606 - val_loss: 0.5385 - val_auc: 0.6832
# Epoch 166/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6718 - auc: 0.4927 - val_loss: 0.5383 - val_auc: 0.6913
# Epoch 167/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6718 - auc: 0.5081 - val_loss: 0.5380 - val_auc: 0.6960
# Epoch 168/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6701 - auc: 0.4965 - val_loss: 0.5379 - val_auc: 0.6936
# Epoch 169/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6666 - auc: 0.5038 - val_loss: 0.5377 - val_auc: 0.7025
# Epoch 170/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.6654 - auc: 0.5016 - val_loss: 0.5375 - val_auc: 0.7003
# Epoch 171/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6664 - auc: 0.4738 - val_loss: 0.5375 - val_auc: 0.7047
# Epoch 172/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.6638 - auc: 0.5478 - val_loss: 0.5374 - val_auc: 0.7052
# Epoch 173/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6629 - auc: 0.5447 - val_loss: 0.5373 - val_auc: 0.7152
# Epoch 174/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.6617 - auc: 0.5191 - val_loss: 0.5371 - val_auc: 0.7222
# Epoch 175/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6612 - auc: 0.5296 - val_loss: 0.5368 - val_auc: 0.7316
# Epoch 176/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6596 - auc: 0.5377 - val_loss: 0.5366 - val_auc: 0.7356
# Epoch 177/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6601 - auc: 0.5173 - val_loss: 0.5366 - val_auc: 0.7382
# Epoch 178/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6589 - auc: 0.4414 - val_loss: 0.5365 - val_auc: 0.7423
# Epoch 179/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.6538 - auc: 0.4869 - val_loss: 0.5364 - val_auc: 0.7453
# Epoch 180/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6561 - auc: 0.5744 - val_loss: 0.5361 - val_auc: 0.7522
# Epoch 181/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6535 - auc: 0.5068 - val_loss: 0.5360 - val_auc: 0.7541
# Epoch 182/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6518 - auc: 0.5185 - val_loss: 0.5360 - val_auc: 0.7650
# Epoch 183/1000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.6549 - auc: 0.4883 - val_loss: 0.5360 - val_auc: 0.7697
# Epoch 184/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6524 - auc: 0.4871 - val_loss: 0.5358 - val_auc: 0.7789
# Epoch 185/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.6486 - auc: 0.5514 - val_loss: 0.5357 - val_auc: 0.7848
# Epoch 186/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6478 - auc: 0.5205 - val_loss: 0.5356 - val_auc: 0.7972
# Epoch 187/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6466 - auc: 0.5224 - val_loss: 0.5356 - val_auc: 0.8005
# Epoch 188/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6435 - auc: 0.6207 - val_loss: 0.5356 - val_auc: 0.8034
# Epoch 189/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6474 - auc: 0.5097 - val_loss: 0.5357 - val_auc: 0.8243
# Epoch 190/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6447 - auc: 0.5573 - val_loss: 0.5358 - val_auc: 0.8377
# Epoch 191/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6415 - auc: 0.5446 - val_loss: 0.5357 - val_auc: 0.8431
# Epoch 192/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6428 - auc: 0.5274 - val_loss: 0.5357 - val_auc: 0.8470
# Epoch 193/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6420 - auc: 0.5496 - val_loss: 0.5358 - val_auc: 0.8541
# Epoch 194/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6382 - auc: 0.5841 - val_loss: 0.5358 - val_auc: 0.8526
# Epoch 195/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6404 - auc: 0.5090 - val_loss: 0.5360 - val_auc: 0.8521
# Epoch 196/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.6387 - auc: 0.5572 - val_loss: 0.5364 - val_auc: 0.8571
# Epoch 197/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6358 - auc: 0.5129 - val_loss: 0.5366 - val_auc: 0.8563
# Epoch 198/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.6352 - auc: 0.5697 - val_loss: 0.5365 - val_auc: 0.8576
# Epoch 199/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6336 - auc: 0.5371 - val_loss: 0.5367 - val_auc: 0.8686
# Epoch 200/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6342 - auc: 0.5505 - val_loss: 0.5367 - val_auc: 0.8728
# Epoch 201/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6321 - auc: 0.5385 - val_loss: 0.5370 - val_auc: 0.8723
# Epoch 202/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6335 - auc: 0.5217 - val_loss: 0.5371 - val_auc: 0.8763
# Epoch 203/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6297 - auc: 0.5231 - val_loss: 0.5372 - val_auc: 0.8765
# Epoch 204/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6295 - auc: 0.5284 - val_loss: 0.5373 - val_auc: 0.8750
# Epoch 205/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.6268 - auc: 0.5907 - val_loss: 0.5375 - val_auc: 0.8744
# Epoch 206/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6263 - auc: 0.5833 - val_loss: 0.5376 - val_auc: 0.8742
# Epoch 207/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6275 - auc: 0.5596 - val_loss: 0.5376 - val_auc: 0.8719
# Epoch 208/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6253 - auc: 0.5503 - val_loss: 0.5377 - val_auc: 0.8731
# Epoch 209/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.6222 - auc: 0.5463 - val_loss: 0.5378 - val_auc: 0.8766
# Epoch 210/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6238 - auc: 0.5896 - val_loss: 0.5379 - val_auc: 0.8822
# Epoch 211/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6221 - auc: 0.5590 - val_loss: 0.5378 - val_auc: 0.8842
# Epoch 212/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6213 - auc: 0.5889 - val_loss: 0.5375 - val_auc: 0.8910
# Epoch 213/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6202 - auc: 0.5817 - val_loss: 0.5372 - val_auc: 0.8968
# Epoch 214/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.6184 - auc: 0.6027 - val_loss: 0.5370 - val_auc: 0.8953
# Epoch 215/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6185 - auc: 0.5392 - val_loss: 0.5368 - val_auc: 0.8919
# Epoch 216/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6160 - auc: 0.5162 - val_loss: 0.5362 - val_auc: 0.8913
# Epoch 217/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.6157 - auc: 0.5874 - val_loss: 0.5356 - val_auc: 0.8914
# Epoch 218/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6142 - auc: 0.5612 - val_loss: 0.5352 - val_auc: 0.8904
# Epoch 219/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6127 - auc: 0.5482 - val_loss: 0.5349 - val_auc: 0.8863
# Epoch 220/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.6116 - auc: 0.6054 - val_loss: 0.5346 - val_auc: 0.8860
# Epoch 221/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.6109 - auc: 0.5740 - val_loss: 0.5343 - val_auc: 0.8870
# Epoch 222/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.6095 - auc: 0.6103 - val_loss: 0.5340 - val_auc: 0.8840
# Epoch 223/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6084 - auc: 0.5879 - val_loss: 0.5334 - val_auc: 0.8856
# Epoch 224/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6087 - auc: 0.5572 - val_loss: 0.5328 - val_auc: 0.8876
# Epoch 225/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6071 - auc: 0.5784 - val_loss: 0.5323 - val_auc: 0.8870
# Epoch 226/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6054 - auc: 0.5525 - val_loss: 0.5319 - val_auc: 0.8900
# Epoch 227/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.6068 - auc: 0.5829 - val_loss: 0.5313 - val_auc: 0.8877
# Epoch 228/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.6028 - auc: 0.5848 - val_loss: 0.5309 - val_auc: 0.8854
# Epoch 229/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6015 - auc: 0.5733 - val_loss: 0.5303 - val_auc: 0.8912
# Epoch 230/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.6011 - auc: 0.5401 - val_loss: 0.5296 - val_auc: 0.8875
# Epoch 231/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.6007 - auc: 0.5660 - val_loss: 0.5287 - val_auc: 0.8904
# Epoch 232/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5987 - auc: 0.5823 - val_loss: 0.5278 - val_auc: 0.8935
# Epoch 233/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6008 - auc: 0.6468 - val_loss: 0.5272 - val_auc: 0.8956
# Epoch 234/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5980 - auc: 0.5832 - val_loss: 0.5265 - val_auc: 0.8944
# Epoch 235/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5971 - auc: 0.6131 - val_loss: 0.5258 - val_auc: 0.8967
# Epoch 236/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5945 - auc: 0.5951 - val_loss: 0.5252 - val_auc: 0.8987
# Epoch 237/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5929 - auc: 0.6026 - val_loss: 0.5246 - val_auc: 0.8971
# Epoch 238/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5940 - auc: 0.6000 - val_loss: 0.5240 - val_auc: 0.8965
# Epoch 239/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.5917 - auc: 0.6134 - val_loss: 0.5234 - val_auc: 0.9001
# Epoch 240/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5911 - auc: 0.6118 - val_loss: 0.5227 - val_auc: 0.9030
# Epoch 241/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5902 - auc: 0.6245 - val_loss: 0.5221 - val_auc: 0.9047
# Epoch 242/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5874 - auc: 0.5945 - val_loss: 0.5214 - val_auc: 0.9037
# Epoch 243/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5877 - auc: 0.6227 - val_loss: 0.5209 - val_auc: 0.9008
# Epoch 244/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.5870 - auc: 0.6203 - val_loss: 0.5204 - val_auc: 0.9014
# Epoch 245/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5860 - auc: 0.6142 - val_loss: 0.5198 - val_auc: 0.8958
# Epoch 246/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5869 - auc: 0.5828 - val_loss: 0.5193 - val_auc: 0.8947
# Epoch 247/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5839 - auc: 0.5788 - val_loss: 0.5187 - val_auc: 0.8923
# Epoch 248/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5827 - auc: 0.6006 - val_loss: 0.5179 - val_auc: 0.8970
# Epoch 249/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5818 - auc: 0.5726 - val_loss: 0.5168 - val_auc: 0.8933
# Epoch 250/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5803 - auc: 0.6013 - val_loss: 0.5157 - val_auc: 0.8989
# Epoch 251/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5801 - auc: 0.6248 - val_loss: 0.5145 - val_auc: 0.8975
# Epoch 252/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.5787 - auc: 0.6432 - val_loss: 0.5133 - val_auc: 0.9034
# Epoch 253/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5785 - auc: 0.6020 - val_loss: 0.5121 - val_auc: 0.9096
# Epoch 254/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5763 - auc: 0.6533 - val_loss: 0.5108 - val_auc: 0.9153
# Epoch 255/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5747 - auc: 0.6278 - val_loss: 0.5096 - val_auc: 0.9161
# Epoch 256/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5745 - auc: 0.5887 - val_loss: 0.5085 - val_auc: 0.9196
# Epoch 257/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5718 - auc: 0.6539 - val_loss: 0.5074 - val_auc: 0.9182
# Epoch 258/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5714 - auc: 0.6069 - val_loss: 0.5065 - val_auc: 0.9178
# Epoch 259/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5718 - auc: 0.5646 - val_loss: 0.5056 - val_auc: 0.9148
# Epoch 260/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.5700 - auc: 0.6277 - val_loss: 0.5045 - val_auc: 0.9125
# Epoch 261/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.5698 - auc: 0.5795 - val_loss: 0.5036 - val_auc: 0.9161
# Epoch 262/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5686 - auc: 0.5715 - val_loss: 0.5027 - val_auc: 0.9211
# Epoch 263/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5679 - auc: 0.6299 - val_loss: 0.5018 - val_auc: 0.9168
# Epoch 264/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.5659 - auc: 0.6341 - val_loss: 0.5009 - val_auc: 0.9106
# Epoch 265/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5634 - auc: 0.6441 - val_loss: 0.5000 - val_auc: 0.9151
# Epoch 266/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.5636 - auc: 0.6064 - val_loss: 0.4989 - val_auc: 0.9200
# Epoch 267/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5619 - auc: 0.6469 - val_loss: 0.4979 - val_auc: 0.9241
# Epoch 268/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.5608 - auc: 0.6424 - val_loss: 0.4969 - val_auc: 0.9217
# Epoch 269/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5608 - auc: 0.6054 - val_loss: 0.4958 - val_auc: 0.9152
# Epoch 270/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.5589 - auc: 0.6581 - val_loss: 0.4947 - val_auc: 0.9180
# Epoch 271/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.5573 - auc: 0.6417 - val_loss: 0.4936 - val_auc: 0.9156
# Epoch 272/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5565 - auc: 0.6337 - val_loss: 0.4925 - val_auc: 0.9173
# Epoch 273/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5534 - auc: 0.6761 - val_loss: 0.4913 - val_auc: 0.9099
# Epoch 274/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5522 - auc: 0.7033 - val_loss: 0.4901 - val_auc: 0.9097
# Epoch 275/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5528 - auc: 0.6595 - val_loss: 0.4889 - val_auc: 0.9144
# Epoch 276/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5495 - auc: 0.6778 - val_loss: 0.4877 - val_auc: 0.9172
# Epoch 277/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5487 - auc: 0.6476 - val_loss: 0.4866 - val_auc: 0.9141
# Epoch 278/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5473 - auc: 0.6402 - val_loss: 0.4855 - val_auc: 0.9059
# Epoch 279/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.5479 - auc: 0.6245 - val_loss: 0.4843 - val_auc: 0.9064
# Epoch 280/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5448 - auc: 0.6479 - val_loss: 0.4831 - val_auc: 0.9078
# Epoch 281/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.5434 - auc: 0.6261 - val_loss: 0.4820 - val_auc: 0.9120
# Epoch 282/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5420 - auc: 0.6372 - val_loss: 0.4811 - val_auc: 0.9137
# Epoch 283/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5405 - auc: 0.6408 - val_loss: 0.4802 - val_auc: 0.9182
# Epoch 284/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5397 - auc: 0.6387 - val_loss: 0.4793 - val_auc: 0.9106
# Epoch 285/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5373 - auc: 0.6548 - val_loss: 0.4782 - val_auc: 0.9105
# Epoch 286/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5362 - auc: 0.6656 - val_loss: 0.4771 - val_auc: 0.9083
# Epoch 287/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.5348 - auc: 0.6777 - val_loss: 0.4759 - val_auc: 0.9105
# Epoch 288/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5319 - auc: 0.6265 - val_loss: 0.4747 - val_auc: 0.9093
# Epoch 289/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5310 - auc: 0.6441 - val_loss: 0.4735 - val_auc: 0.9173
# Epoch 290/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5302 - auc: 0.6699 - val_loss: 0.4722 - val_auc: 0.9233
# Epoch 291/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5273 - auc: 0.6612 - val_loss: 0.4710 - val_auc: 0.9120
# Epoch 292/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5273 - auc: 0.6833 - val_loss: 0.4697 - val_auc: 0.9021
# Epoch 293/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5260 - auc: 0.6680 - val_loss: 0.4686 - val_auc: 0.9054
# Epoch 294/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5244 - auc: 0.6973 - val_loss: 0.4675 - val_auc: 0.9084
# Epoch 295/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.5234 - auc: 0.6390 - val_loss: 0.4664 - val_auc: 0.9115
# Epoch 296/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5215 - auc: 0.6834 - val_loss: 0.4654 - val_auc: 0.9242
# Epoch 297/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5215 - auc: 0.6790 - val_loss: 0.4644 - val_auc: 0.9276
# Epoch 298/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.5196 - auc: 0.6541 - val_loss: 0.4634 - val_auc: 0.9242
# Epoch 299/1000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.5189 - auc: 0.6860 - val_loss: 0.4623 - val_auc: 0.9240
# Epoch 300/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5189 - auc: 0.6641 - val_loss: 0.4612 - val_auc: 0.9239
# Epoch 301/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5163 - auc: 0.6779 - val_loss: 0.4602 - val_auc: 0.9231
# Epoch 302/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5150 - auc: 0.6510 - val_loss: 0.4592 - val_auc: 0.9200
# Epoch 303/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5144 - auc: 0.6806 - val_loss: 0.4584 - val_auc: 0.9172
# Epoch 304/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.5140 - auc: 0.6400 - val_loss: 0.4575 - val_auc: 0.9295
# Epoch 305/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5122 - auc: 0.6566 - val_loss: 0.4566 - val_auc: 0.9374
# Epoch 306/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5106 - auc: 0.6650 - val_loss: 0.4557 - val_auc: 0.9331
# Epoch 307/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5098 - auc: 0.6897 - val_loss: 0.4548 - val_auc: 0.9273
# Epoch 308/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.5087 - auc: 0.6961 - val_loss: 0.4539 - val_auc: 0.9266
# Epoch 309/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.5082 - auc: 0.6660 - val_loss: 0.4531 - val_auc: 0.9250
# Epoch 310/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5060 - auc: 0.6680 - val_loss: 0.4522 - val_auc: 0.9227
# Epoch 311/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5073 - auc: 0.6884 - val_loss: 0.4514 - val_auc: 0.9198
# Epoch 312/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5050 - auc: 0.6906 - val_loss: 0.4505 - val_auc: 0.9218
# Epoch 313/1000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.5045 - auc: 0.6849 - val_loss: 0.4496 - val_auc: 0.9392
# Epoch 314/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.5036 - auc: 0.6949 - val_loss: 0.4487 - val_auc: 0.9345
# Epoch 315/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.5011 - auc: 0.6963 - val_loss: 0.4479 - val_auc: 0.9290
# Epoch 316/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5018 - auc: 0.6923 - val_loss: 0.4472 - val_auc: 0.9278
# Epoch 317/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.5005 - auc: 0.6706 - val_loss: 0.4463 - val_auc: 0.9321
# Epoch 318/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4989 - auc: 0.6869 - val_loss: 0.4455 - val_auc: 0.9299
# Epoch 319/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4966 - auc: 0.6825 - val_loss: 0.4447 - val_auc: 0.9271
# Epoch 320/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4974 - auc: 0.6729 - val_loss: 0.4439 - val_auc: 0.9295
# Epoch 321/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4947 - auc: 0.7344 - val_loss: 0.4431 - val_auc: 0.9266
# Epoch 322/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.4952 - auc: 0.6704 - val_loss: 0.4423 - val_auc: 0.9289
# Epoch 323/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.4940 - auc: 0.7071 - val_loss: 0.4415 - val_auc: 0.9261
# Epoch 324/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.4937 - auc: 0.7023 - val_loss: 0.4407 - val_auc: 0.9337
# Epoch 325/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4919 - auc: 0.6986 - val_loss: 0.4401 - val_auc: 0.9382
# Epoch 326/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4918 - auc: 0.7117 - val_loss: 0.4394 - val_auc: 0.9365
# Epoch 327/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4909 - auc: 0.6923 - val_loss: 0.4387 - val_auc: 0.9339
# Epoch 328/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.4904 - auc: 0.7240 - val_loss: 0.4381 - val_auc: 0.9367
# Epoch 329/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4892 - auc: 0.7191 - val_loss: 0.4374 - val_auc: 0.9332
# Epoch 330/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.4877 - auc: 0.7202 - val_loss: 0.4368 - val_auc: 0.9244
# Epoch 331/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4883 - auc: 0.7033 - val_loss: 0.4363 - val_auc: 0.9259
# Epoch 332/1000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.4868 - auc: 0.6774 - val_loss: 0.4358 - val_auc: 0.9221
# Epoch 333/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4850 - auc: 0.7473 - val_loss: 0.4352 - val_auc: 0.9236
# Epoch 334/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4852 - auc: 0.6753 - val_loss: 0.4346 - val_auc: 0.9252
# Epoch 335/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4834 - auc: 0.7507 - val_loss: 0.4340 - val_auc: 0.9272
# Epoch 336/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.4825 - auc: 0.7079 - val_loss: 0.4333 - val_auc: 0.9384
# Epoch 337/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4801 - auc: 0.7859 - val_loss: 0.4328 - val_auc: 0.9430
# Epoch 338/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4810 - auc: 0.7033 - val_loss: 0.4323 - val_auc: 0.9410
# Epoch 339/1000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.4794 - auc: 0.7387 - val_loss: 0.4318 - val_auc: 0.9278
# Epoch 340/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4800 - auc: 0.7119 - val_loss: 0.4312 - val_auc: 0.9244
# Epoch 341/1000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.4787 - auc: 0.6804 - val_loss: 0.4307 - val_auc: 0.9262
# Epoch 342/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4770 - auc: 0.6963 - val_loss: 0.4302 - val_auc: 0.9274
# Epoch 343/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.4765 - auc: 0.7215 - val_loss: 0.4296 - val_auc: 0.9282
# Epoch 344/1000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4748 - auc: 0.7412 - val_loss: 0.4291 - val_auc: 0.9129
# Epoch 345/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4745 - auc: 0.7317 - val_loss: 0.4285 - val_auc: 0.9140
# Epoch 346/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4739 - auc: 0.7400 - val_loss: 0.4279 - val_auc: 0.9154
# Epoch 347/1000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.4734 - auc: 0.7026 - val_loss: 0.4274 - val_auc: 0.9169
# Epoch 348/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4723 - auc: 0.7056 - val_loss: 0.4269 - val_auc: 0.9184
# Epoch 349/1000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4715 - auc: 0.6940 - val_loss: 0.4263 - val_auc: 0.9336
# Epoch 350/1000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.4710 - auc: 0.7321 - val_loss: 0.4258 - val_auc: 0.9373
# Epoch 351/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4703 - auc: 0.7635 - val_loss: 0.4253 - val_auc: 0.9288
# Epoch 352/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4688 - auc: 0.7257 - val_loss: 0.4248 - val_auc: 0.9265
# Epoch 353/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4691 - auc: 0.6816 - val_loss: 0.4243 - val_auc: 0.9227
# Epoch 354/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4668 - auc: 0.7524 - val_loss: 0.4239 - val_auc: 0.9179
# Epoch 355/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4667 - auc: 0.6920 - val_loss: 0.4234 - val_auc: 0.9249
# Epoch 356/1000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.4656 - auc: 0.7220 - val_loss: 0.4228 - val_auc: 0.9261
# Epoch 357/1000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4639 - auc: 0.7366 - val_loss: 0.4224 - val_auc: 0.9269
# Epoch 358/1000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4644 - auc: 0.7291 - val_loss: 0.4220 - val_auc: 0.9220
# Epoch 359/1000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4626 - auc: 0.7622 - val_loss: 0.4216 - val_auc: 0.9224
# Epoch 360/1000
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4660 - auc: 0.6693

# %% [markdown]
# batch size: 65536\
# epochs: 3000\
# EarlyStopping: Yes

# %%
score = model.evaluate(x_test, y_test)
print(score)
# Out:
# 1781/1781 [==============================] - 6s 3ms/step - loss: 0.0038 - auc: 0.9032
# [0.0037894078996032476, 0.9031928181648254]

# %% [markdown]
# # Training Visualization

# %%
plt.figure(figsize = (30,15))

plt.subplot(3,1,1)
plt.plot(history.history["loss"], label = "Loss")
plt.plot(history.history["val_loss"], label = "Val_Loss")
plt.title("Training Loss & Validate Loss")
plt.legend()

plt.subplot(3,1,2)
plt.plot(history.history["precision"], label = "Precision")
plt.plot(history.history["val_precision"], label = "Val_Precision")
plt.title("Training Precision & Validate Precision")
plt.legend()

plt.subplot(3,1,3)
plt.plot(history.history["recall"], label = "Recall")
plt.plot(history.history["val_recall"], label = "Val_Recall")
plt.title("Training Recall & Validate Recall")
plt.legend()

# %% [markdown]
# # ANN Performance

# %%
Ann_predict = tf.cast( model.predict(x_test) > 0.5, dtype = tf.float32)
print("Test Report = \n", classification_report(Ann_predict, y_test))
# Out:
# 1781/1781 [==============================] - 4s 2ms/step
# Test Report =
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56908
#          1.0       0.58      1.00      0.73        54
#
#     accuracy                           1.00     56962
#    macro avg       0.79      1.00      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# # Other Machine Learning Method

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2, random_state=22)

# %% [markdown]
# 다른 Machine Learning Method는 EarlyStopping을 사용하지 않으므로 validation set을 만들지 않고, 모두 training data로 사용한다.

# %% [markdown]
# # 1) XGboost

# %%
from xgboost import XGBClassifier

Xgboost_model = XGBClassifier()
Xgboost_model.fit(x_train, y_train, eval_metric='aucpr')

Xg_predict = tf.cast( Xgboost_model.predict(x_test) > 0.5, dtype = tf.float32)
print("Test Report = \n", classification_report(Xg_predict, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Test Report =
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56879
#          1.0       0.84      0.94      0.89        83
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.97      0.94     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# # 2) RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

RandomForest_model = RandomForestClassifier(n_estimators=100, oob_score=False)
RandomForest_model.fit(x_train, y_train)

RF_predict = tf.cast( RandomForest_model.predict(x_test) > 0.5, dtype = tf.float32)
print("Test Report = \n", classification_report(RF_predict, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# Test Report =
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     56883
#          1.0       0.82      0.96      0.88        79
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.98      0.94     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# # 3) Light Gradient Boosting

# %%
from lightgbm import LGBMClassifier

LGBM_model = LGBMClassifier()
LGBM_model.fit(x_train, y_train, eval_metric='aucpr')

LGBM_predict = tf.cast( LGBM_model.predict(x_test) > 0.5, dtype = tf.float32)
print("Test Report = \n", classification_report(LGBM_predict, y_test))

# %% [markdown]
# # 4) Support Vector Machine

# %%
from sklearn.svm import SVC

SVC_model = SVC(kernel="rbf")
SVC_model.fit(x_train, y_train)

SVC_predict = tf.cast( SVC_model.predict(x_test) > 0.5, dtype = tf.float32)
print("Test Report = \n", classification_report(SVC_predict, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-8f764b753d54> in <module>
#       2
#       3 SVC_model = SVC(C=7, kernel="rbf", probability=True)
# ----> 4 SVC_model.fit(x_train, y_train)
#       5
#       6 SVC_predict = tf.cast( SVC_model.predict(x_test) > 0.5, dtype = tf.float32)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     253
#     254         seed = rnd.randint(np.iinfo("i").max)
# --> 255         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     256         # see comment on the other call to np.iinfo in this file
#     257
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     331             epsilon=self.epsilon,
#     332             max_iter=self.max_iter,
# --> 333             random_seed=random_seed,
#     334         )
#     335
#
# KeyboardInterrupt:

# %% [markdown]
# # Model Comparison

# %%
F1_dict={}
F1_dict["ANN"] = f1_score(Ann_predict, y_test)
F1_dict["XGboost"] = f1_score(Xg_predict, y_test)
F1_dict["RandomForest"] = f1_score(RF_predict, y_test)
F1_dict["LGBM"] = f1_score(LGBM_predict, y_test)
F1_dict["SVM"] = f1_score(SVC_predict, y_test)

# %%
F1_df = pd.DataFrame(F1_dict)
F1_df.plot(kind='barh', figsize=(15, 8))
